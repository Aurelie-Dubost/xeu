# %%
import pandas as pd

# %%
def rgb_string_to_tuple(rgb_string):
    """ Convert an RGB string 'rgb(x, y, z)' to a normalized RGB tuple. """
    rgb = rgb_string.strip('rgb()').split(',')
    return tuple(int(num) / 255 for num in rgb)

def get_colors(style, inverted):
    """ Return appropriate colors based on style and inversion. """
    color_config = {
        'col_scale': ['rgb(214, 95, 95)', 'rgb(95, 186, 125)'],  # Red to Green
        'bar': ['rgb(214, 95, 95)', 'rgb(95, 186, 125)']  # Red for negative, Green for positive
    }
    
    if style not in color_config:
        raise ValueError(f"Style {style} is not supported. Available styles: {list(color_config.keys())}")
    
    colors = color_config[style]
    return colors[::-1] if inverted else colors

def initialize_styler(df):
    """ Initialize DataFrame styler with common properties. """
    return df.style.set_properties(
        **{'background-color': 'white', 'text-align': 'center', 'border': '1px solid black'}
    ).set_table_styles(
        [{'selector': 'th', 'props': [('text-align', 'center')]}]
    )
    
def apply_bar_style(df, columns, colors):
    """ Apply bar style to columns with specified RGB colors. """
    styler = initialize_styler(df)
    for column in columns:
        styler = styler.bar(subset=[column], align='mid', color=colors)
    return styler

def apply_gradient_style(df, column, colors, q_low, q_high):
    """ Apply gradient style to a column based on quantiles with given RGB colors. """
    from matplotlib.colors import LinearSegmentedColormap

    # Convert RGB string colors to normalized RGB tuples
    colors = [rgb_string_to_tuple(color) for color in colors]

    cmap = LinearSegmentedColormap.from_list("custom_cmap", colors)
    quantile_low = df[column].quantile(q_low / 100.0)
    quantile_high = df[column].quantile(q_high / 100.0)
    styler = initialize_styler(df)
    return styler.background_gradient(subset=[column], cmap=cmap, vmin=quantile_low, vmax=quantile_high, axis=0)

def apply_custom_style(df, columns, style, params=None, inverted=False):
    if not isinstance(columns, list):
        columns = [columns]  # Ensure columns is a list for uniform processing

    colors = get_colors(style, inverted)

    if style == 'col_scale':
        if not params or len(params) != 2:
            raise ValueError("Params must be a tuple with two percentage values for 'col_scale'")
        # Initialize the styler from the DataFrame
        styler = initialize_styler(df)
        q_low, q_high = params
        for column in columns:
            # Apply gradient style and keep chaining the styling
            styler = apply_gradient_style(df, column, colors, q_low, q_high)
        return styler  # Return the fully styled DataFrame

    elif style == 'bar':
        return apply_bar_style(df, columns, colors)

    else:
        raise ValueError("Unsupported style option. Choose 'col_scale', 'bar', or 'icon'")

# %%
import pandas as pd

# Example DataFrame
data = {
    'Product': ['Laptop', 'Printer', 'Tablet', 'Desk', 'Chair'],
    'Sales': [1000, 300, 450, 150, 700],
    'Profit': [200, -60, 90, -30, 140]
}
df = pd.DataFrame(data)

# %%
# Apply bar style
styled_df_bar = apply_custom_style(df, ['Profit'], 'bar', inverted=True)
# Display styled DataFrames in a Jupyter Notebook:
styled_df_bar
# Out:
# <style type="text/css">
# #T_dc153 th {
#   text-align: center;
# }
# #T_dc153_row0_col0, #T_dc153_row0_col1, #T_dc153_row1_col0, #T_dc153_row1_col1, #T_dc153_row2_col0, #T_dc153_row2_col1, #T_dc153_row3_col0, #T_dc153_row3_col1, #T_dc153_row4_col0, #T_dc153_row4_col1 {
#   background-color: white;
#   text-align: center;
#   border: 1px solid black;
# }
# #T_dc153_row0_col2 {
#   background-color: white;
#   text-align: center;
#   border: 1px solid black;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 23.1%, rgb(214, 95, 95) 23.1%, rgb(214, 95, 95) 100.0%, transparent 100.0%);
# }
# #T_dc153_row1_col2 {
#   background-color: white;
#   text-align: center;
#   border: 1px solid black;
#   width: 10em;
#   background: linear-gradient(90deg, rgb(95, 186, 125) 23.1%, transparent 23.1%);
# }
# #T_dc153_row2_col2 {
#   background-color: white;
#   text-align: center;
#   border: 1px solid black;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 23.1%, rgb(214, 95, 95) 23.1%, rgb(214, 95, 95) 57.7%, transparent 57.7%);
# }
# #T_dc153_row3_col2 {
#   background-color: white;
#   text-align: center;
#   border: 1px solid black;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 11.5%, rgb(95, 186, 125) 11.5%, rgb(95, 186, 125) 23.1%, transparent 23.1%);
# }
# #T_dc153_row4_col2 {
#   background-color: white;
#   text-align: center;
#   border: 1px solid black;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 23.1%, rgb(214, 95, 95) 23.1%, rgb(214, 95, 95) 76.9%, transparent 76.9%);
# }
# </style>
# <table id="T_dc153">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc153_level0_col0" class="col_heading level0 col0" >Product</th>
#       <th id="T_dc153_level0_col1" class="col_heading level0 col1" >Sales</th>
#       <th id="T_dc153_level0_col2" class="col_heading level0 col2" >Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc153_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dc153_row0_col0" class="data row0 col0" >Laptop</td>
#       <td id="T_dc153_row0_col1" class="data row0 col1" >1000</td>
#       <td id="T_dc153_row0_col2" class="data row0 col2" >200</td>
#     </tr>
#     <tr>
#       <th id="T_dc153_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dc153_row1_col0" class="data row1 col0" >Printer</td>
#       <td id="T_dc153_row1_col1" class="data row1 col1" >300</td>
#       <td id="T_dc153_row1_col2" class="data row1 col2" >-60</td>
#     </tr>
#     <tr>
#       <th id="T_dc153_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dc153_row2_col0" class="data row2 col0" >Tablet</td>
#       <td id="T_dc153_row2_col1" class="data row2 col1" >450</td>
#       <td id="T_dc153_row2_col2" class="data row2 col2" >90</td>
#     </tr>
#     <tr>
#       <th id="T_dc153_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dc153_row3_col0" class="data row3 col0" >Desk</td>
#       <td id="T_dc153_row3_col1" class="data row3 col1" >150</td>
#       <td id="T_dc153_row3_col2" class="data row3 col2" >-30</td>
#     </tr>
#     <tr>
#       <th id="T_dc153_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dc153_row4_col0" class="data row4 col0" >Chair</td>
#       <td id="T_dc153_row4_col1" class="data row4 col1" >700</td>
#       <td id="T_dc153_row4_col2" class="data row4 col2" >140</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Apply color scale style
styled_df_col_scale = apply_custom_style(df, ['Sales'], 'col_scale', params=(10, 90), inverted=False)
styled_df_col_scale
# Out:
# <style type="text/css">
# #T_a66ef th {
#   text-align: center;
# }
# #T_a66ef_row0_col0, #T_a66ef_row0_col2, #T_a66ef_row1_col0, #T_a66ef_row1_col2, #T_a66ef_row2_col0, #T_a66ef_row2_col2, #T_a66ef_row3_col0, #T_a66ef_row3_col2, #T_a66ef_row4_col0, #T_a66ef_row4_col2 {
#   background-color: white;
#   text-align: center;
#   border: 1px solid black;
# }
# #T_a66ef_row0_col1 {
#   background-color: white;
#   text-align: center;
#   border: 1px solid black;
#   background-color: #5fba7d;
#   color: #f1f1f1;
# }
# #T_a66ef_row1_col1 {
#   background-color: white;
#   text-align: center;
#   border: 1px solid black;
#   background-color: #c66b63;
#   color: #f1f1f1;
# }
# #T_a66ef_row2_col1 {
#   background-color: white;
#   text-align: center;
#   border: 1px solid black;
#   background-color: #ac7f6a;
#   color: #f1f1f1;
# }
# #T_a66ef_row3_col1 {
#   background-color: white;
#   text-align: center;
#   border: 1px solid black;
#   background-color: #d65f5f;
#   color: #f1f1f1;
# }
# #T_a66ef_row4_col1 {
#   background-color: white;
#   text-align: center;
#   border: 1px solid black;
#   background-color: #7fa275;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a66ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a66ef_level0_col0" class="col_heading level0 col0" >Product</th>
#       <th id="T_a66ef_level0_col1" class="col_heading level0 col1" >Sales</th>
#       <th id="T_a66ef_level0_col2" class="col_heading level0 col2" >Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a66ef_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a66ef_row0_col0" class="data row0 col0" >Laptop</td>
#       <td id="T_a66ef_row0_col1" class="data row0 col1" >1000</td>
#       <td id="T_a66ef_row0_col2" class="data row0 col2" >200</td>
#     </tr>
#     <tr>
#       <th id="T_a66ef_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a66ef_row1_col0" class="data row1 col0" >Printer</td>
#       <td id="T_a66ef_row1_col1" class="data row1 col1" >300</td>
#       <td id="T_a66ef_row1_col2" class="data row1 col2" >-60</td>
#     </tr>
#     <tr>
#       <th id="T_a66ef_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a66ef_row2_col0" class="data row2 col0" >Tablet</td>
#       <td id="T_a66ef_row2_col1" class="data row2 col1" >450</td>
#       <td id="T_a66ef_row2_col2" class="data row2 col2" >90</td>
#     </tr>
#     <tr>
#       <th id="T_a66ef_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a66ef_row3_col0" class="data row3 col0" >Desk</td>
#       <td id="T_a66ef_row3_col1" class="data row3 col1" >150</td>
#       <td id="T_a66ef_row3_col2" class="data row3 col2" >-30</td>
#     </tr>
#     <tr>
#       <th id="T_a66ef_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a66ef_row4_col0" class="data row4 col0" >Chair</td>
#       <td id="T_a66ef_row4_col1" class="data row4 col1" >700</td>
#       <td id="T_a66ef_row4_col2" class="data row4 col2" >140</td>
#     </tr>
#   </tbody>
# </table>
